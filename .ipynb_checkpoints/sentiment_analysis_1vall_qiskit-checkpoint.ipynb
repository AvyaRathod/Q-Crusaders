# %% [markdown]
# # Table of contents
# 1. [Dataset Parsing](#vocab)
# 2. [Quantum Circuits](#circuit)
# 3. [Process Dataset](#dataset)
# 4. [Optimization](#optimization)
# 5. [Results](#results)

# %% [markdown]
# # Sentiment analysis
#
# Sentiment analysis is a natural language processing (NLP) technique to determine the sentiment of a sentence. In this implementation, we propose to use quantum natural language processing (QNLP) as an alternative to solve this problem. QNLP enables the resolution of NLP tasks taking advantage of the inherent quantum nature of language, allowing to take into account the grammar of sentences and to work in an exponentially large Hilbert space, easing the memory problems of its classical counterpart.
#
# In this Jupyter Notebook we show how to solve a sentiment analysis problem. More concretely, it is a multi-class classification task where the sentences of a dataset are divided into four categories: happy, sad, angry and scared. As a reference for the resolution of this problem we use the paper by Lorenz et al https://arxiv.org/abs/2102.12846, where they solve a binary classification problem. Their code and resources can be found in https://github.com/CQCL/qnlp_lorenz_etal_2021_resources.

# %% [markdown]
# ## 1. Parse Vocabulary and Grammar <a name="vocab"></a>
#
#
# The first step is to create the dataset for our task. It is important to create a balanced dataset suitable for this problem. In order to do that, we have chosen the following words
#
# | Nouns | Verbs | Adjectives |
# | --- | --- | --- |
# | Man | cries | morose |
# | Woman | laughs | irascible |
# | Kid | shouts | frightened |
# |  | snaps | cheerful |
# |  | entertains | gloomy |
# |  | grieves | furious |
# |  | startles | terrified |
# |  | irritates |joyful|
# |  |  | downcast|
# |  |  | miserable|
# |  |  | old|
# |  |  | young|
#
# We can observe that we have three different types of words: nouns, verbs and adjectives. The information regarding the meaning of the sentence is going to be given by the verb, the adjective or the combination of both, as there are verbs that can be used to express more than one feeling, or adjectives that show no sentiment ('young', 'old')
#
# The proposed vocabulary has 23 words, with which we write 366 sentences, for example
#
#
# - Morose man cries. (morose)
# - Irascible woman shouts. (irascible)
# - Frightened woman shouts. (frightened)
# - Joyful kid laughs. (joyful, laughs)
# - Furious man snaps. (furious)
# - Kid startles man. (startles)
# - Woman grieves man. (grieves)
# ...
#
# The brackets indicate the word or words that enclose the sentiment in each example.
#
# We are going to consider four classes of sentences:
# - Adj + Subject + Intransitive verb
# - Subject + Transitive verb + Object
# - Adjective + Subject + Transitive verb + Object
# - Subject + Transitive verb + Adjective + Object
#
# The steps to construct the dataset are the following ones. We first store the words in DisCoPy's Word objects, encoding their meaning (name) and their grammar (codomain). Then, we introduce the grammar of the allowed sentences and create all the possible grammatical sentences. The next step is to assign a sentiment to each sentence. However, there are sentences that although they are grammatically correct, their meaning makes no sense, so we would have to remove them.

# %% [markdown]
# ### 1.1. Define the vocabulary
#
# The first step to create a dataset is to define the words, their meaning and the word type. We have four three types of words: nouns, adjectives, verbs. We also distinguish two different types of verbs: transitive and intransitive.

# %%
# !pip --version discopy
# Out:
# pip 23.1.2 from /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pip (python 3.11)

# %%
# !pip install discopy==0.3.5
# Out:
# Requirement already satisfied: discopy==0.3.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.3.5)
# Requirement already satisfied: numpy>=1.18.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from discopy==0.3.5) (1.25.2)
# Requirement already satisfied: networkx>=2.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from discopy==0.3.5) (3.1)
# Requirement already satisfied: matplotlib>=3.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from discopy==0.3.5) (3.7.1)
# Requirement already satisfied: pillow>=6.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from discopy==0.3.5) (9.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.1.2->discopy==0.3.5) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.1.2->discopy==0.3.5) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.1.2->discopy==0.3.5) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.1.2->discopy==0.3.5) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.1.2->discopy==0.3.5) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.1.2->discopy==0.3.5) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.1.2->discopy==0.3.5) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.2->discopy==0.3.5) (1.16.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pickle

import qiskit
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.25.1', 'qiskit': '0.44.1', 'qiskit-aer': '0.12.2', 'qiskit-ignis': None, 'qiskit-ibmq-provider': None, 'qiskit-nature': None, 'qiskit-finance': None, 'qiskit-optimization': None, 'qiskit-machine-learning': None}

# %%
from discopy import Ty, Word # Import the classes for the type of word and for the word

s, n = Ty('s'), Ty('n') # Define the types s and n
nphr, adj, tv, iv, vphr = Ty('NP'), Ty('ADJ'), Ty('TV'), Ty('IV'), Ty('VP')

# Define the words (notice that we include both meaning and grammar)

# nouns
man, woman, kid = Word('man', n), Word('woman', n), Word('kid', n)
# adjectives
morose, irascible = Word('morose', n @ n.l), Word('irascible', n @ n.l)
frightened, cheerful = Word('frightened', n @ n.l), Word('cheerful', n @ n.l)
gloomy, furious = Word('gloomy', n @ n.l), Word('furious', n @ n.l)
terrified, joyful = Word('terrified', n @ n.l), Word('joyful', n @ n.l)
downcast, miserable = Word('downcast', n @ n.l), Word('miserable', n @ n.l)
old, young = Word('old', n @ n.l), Word('young', n @ n.l)
# Intransitive verbs
cries, shouts = Word('cries', n.r @ s), Word('shouts', n.r @ s)
laughs, snaps = Word('laughs', n.r @ s), Word('snaps', n.r @ s)
# Transitive verbs
grieves, startles = Word('grieves', n.r @ s @ n.l), Word('startles', n.r @ s @ n.l)
entertains, irritates = Word('entertains', n.r @ s @ n.l), Word('irritates', n.r @ s @ n.l)

nouns = [man, woman, kid]
adjectives = [morose, irascible, frightened, cheerful, gloomy, furious, terrified, joyful, downcast, miserable, old, young]
int_verbs = [cries, shouts, laughs, snaps]
t_verbs = [grieves, startles, entertains, irritates]

vocab = nouns + int_verbs + t_verbs + adjectives

# %% [markdown]
# ### 1.2. Define the grammar
#
# In this dataset we are going to consider the following structures to construct the sentences:
#
# - adj + noun + int. verb
# - noun + t. verb + noun

# %% [markdown]
# - Intransitive sentence

# %%
from discopy import Cup, Id, pregroup

grammar =  Id(n) @ Cup(n.l, n) @ Id(n.r @ s) >> Cup(n, n.r) @ Id(s) >> Id(s)
sentence = joyful @ woman @ laughs >> grammar
pregroup.draw(sentence)

# %% [markdown]
# - Transitive sentence

# %%
grammar =  Cup(n, n.r) @ Id(s) @ Cup(n.l, n)
sentence = woman @ grieves @ kid >> grammar
pregroup.draw(sentence)

# %% [markdown]
# Now we have seen how the grammatical structure of each type of sentence is, so we are ready to obtain all the grammatical sentences that we can construct with them with the vocabulary that we are using.

# %%
from discopy import Diagram
from discopy.grammar import draw

# Store the grammatical structures in a dictionary 

grammar_dict = {
    'ADJ_N_IV' : Id(n) @ Cup(n.l, n) @ Id(n.r @ s) >> Cup(n, n.r) @ Id(s) >> Id(s),
    'N_TV_N': Cup(n, n.r) @ Id(s) @ Cup(n.l, n),
    'ADJ_N_TV_N': Id(n) @ Cup(n.l, n) @ Id(n.r @ s) @ Cup(n.l, n) >> Cup(n, n.r) @ Id(s) >> Id(s),
    'N_TV_ADJ_N': Cup(n, n.r) @ Id(s) @ Cup(n.l, n) @ Cup(n.l, n) >> Id(s)}
                                                                          

# Create parsing (grammatical analysis) dictionary where the grammatical sentences
# are the keys and the associated values are the diagrams (words + grammar)

data_psr = {}

# Intransitive sentences
parsing_int = {"{} {} {}.".format(adj, noun, int_verb): adj @ noun @ int_verb >> grammar_dict['ADJ_N_IV']
            for adj in adjectives for noun in nouns for int_verb in int_verbs}
sentences_int = list(parsing_int.keys())
for sentence in sentences_int:
    diagram = parsing_int[sentence]
    data_psr[sentence] = parsing_int[sentence]

# Transitive sentences (without adjective)
parsing_tra = {"{} {} {}.".format(subj, t_verb, obj):  subj @ t_verb @ obj >> grammar_dict['N_TV_N']
            for subj in nouns for t_verb in t_verbs for obj in nouns}


#Due to time limitations, we are exlcuding transitive sentences with adjectives in this implementation
"""
# Transitive sentences (with adjective)
parsing_tra_ladj = {"{} {} {} {}.".format(adj, subj, t_verb, obj):  adj @ subj @ t_verb @ obj >> grammar_dict['ADJ_N_TV_N']
            for adj in adjectives for subj in nouns for t_verb in t_verbs for obj in nouns}
parsing_tra_radj = {"{} {} {} {}.".format(subj, t_verb, adj, obj):  subj @ t_verb @ adj @ obj >> grammar_dict['N_TV_ADJ_N']
            for subj in nouns for t_verb in t_verbs for adj in adjectives for obj in nouns}

parsing_tra.update(parsing_tra_ladj) #merges transitive adjectives into original dict
parsing_tra.update(parsing_tra_radj)
"""
sentences_tra = list(parsing_tra.keys())
for sentence in sentences_tra:
    diagram = parsing_tra[sentence]
    data_psr[sentence] = parsing_tra[sentence]

# %% [markdown]
# Now, we have the dataset with the sentences and their corresponding meaning and grammar. The next step is to design the corresponding quantum circuits to determine the sentiment for each sentence. We are aiming to distinguish between four different emotions: happy (0), sad (1), angry (2), scared (3). However, some sentences of the dataset cannot be clearly classified according to this criteria (for example, 'Old man cries'). Therefore, the next step is to manually modify the dataset so all the sentences can be classified according to this criteria. In order to do that we will create a .txt file and assign the corresponding class to the viable sentences.

# %% [markdown]
# ### 1.3. Process the data

# %%
with open('./sentiment_analysis_dataset.txt') as f:
    data = f.readlines()

# %%
labels_dict = {} # Dictionary with the labels for each sentence
data_psr_dict = {} # Dictionary with the parsing for each sentence
sent_type = {} # Dictionary with the sentence type for each sentence

print(parsing_tra)
adjective_words = [a.name for a in adjectives]
print(adjective_words)
for sentence in data:
    sentstr = sentence[:-7] #seperates the sentence string from the data at the end
    #print(sentstr, sentence)
    try:
        if sentence[-6:-3] == 'int':
            print(sentence)
            diagram = parsing_int[sentstr]
            data_psr_dict[sentstr] = diagram
            labels_dict[sentstr] = sentence[-2]
            sent_type[sentstr] = 'int'
        elif sentence[-6:-3] == 'tra':
            diagram = parsing_tra[sentstr]
            data_psr_dict[sentstr] = diagram
            labels_dict[sentstr] = sentence[-2]
    
            #ignoring transitive adjective sentences in this run
            """if len(sentstr.split()) == 4:
                if sentstr.split()[0] in adjective_words:
                    sent_type[sentstr] = 'tra_' + 'l' #adjective on the left
                else:
                    sent_type[sentstr] = 'tra_' + 'r' #adjective on the right
            else:
                sent_type[sentstr] = 'tra' #the simple transitive verb sentence type
            """
            sent_type[sentstr] = 'tra'
    except:
        continue
# Out:
# {'man grieves man.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('man', Ty('n')), Word('grieves', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('man', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'man grieves woman.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('man', Ty('n')), Word('grieves', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('woman', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'man grieves kid.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('man', Ty('n')), Word('grieves', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('kid', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'man startles man.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('man', Ty('n')), Word('startles', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('man', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'man startles woman.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('man', Ty('n')), Word('startles', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('woman', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'man startles kid.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('man', Ty('n')), Word('startles', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('kid', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'man entertains man.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('man', Ty('n')), Word('entertains', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('man', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'man entertains woman.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('man', Ty('n')), Word('entertains', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('woman', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'man entertains kid.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('man', Ty('n')), Word('entertains', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('kid', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'man irritates man.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('man', Ty('n')), Word('irritates', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('man', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'man irritates woman.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('man', Ty('n')), Word('irritates', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('woman', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'man irritates kid.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('man', Ty('n')), Word('irritates', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('kid', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'woman grieves man.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('woman', Ty('n')), Word('grieves', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('man', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'woman grieves woman.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('woman', Ty('n')), Word('grieves', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('woman', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'woman grieves kid.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('woman', Ty('n')), Word('grieves', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('kid', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), Cup(Ty(Ob('n', z=-1)), Ty('n'))], offsets=[0, 1, 4, 0, 1]), 'woman startles man.': Diagram(dom=Ty(), cod=Ty('s'), boxes=[Word('woman', Ty('n')), Word('startles', Ty(Ob('n', z=1), 's', Ob('n', z=-1))), Word('man', Ty('n')), Cup(Ty('n'), Ty(Ob('n', z=1))), C ...
# ['morose', 'irascible', 'frightened', 'cheerful', 'gloomy', 'furious', 'terrified', 'joyful', 'downcast', 'miserable', 'old', 'young']
# morose woman cries._int_1
#
# morose woman shouts._int_1
#
# morose man cries._int_1
#
# morose man shouts._int_1
#
# morose kid cries._int_1
#
# morose kid shouts._int_1
#
# irascible woman cries._int_2
#
# irascible woman shouts._int_2
#
# irascible woman snaps._int_2
#
# irascible man cries._int_2
#
# irascible man shouts._int_2
#
# irascible man snaps._int_2
#
# irascible kid cries._int_2
#
# irascible kid shouts._int_2
#
# irascible kid snaps._int_2
#
# frightened woman cries._int_3
#
# frightened woman shouts._int_3
#
# frightened woman snaps._int_3
#
# frightened man cries._int_3
#
# frightened man shouts._int_3
#
# frightened man snaps._int_3
#
# frightened kid cries._int_3
#
# frightened kid shouts._int_3
#
# frightened kid snaps._int_3
#
# cheerful woman cries._int_0
#
# cheerful woman laughs._int_0
#
# cheerful woman shouts._int_0
#
# cheerful man cries._int_0
#
# cheerful man shouts._int_0
#
# cheerful man laughs._int_0
#
# cheerful kid cries._int_0
#
# cheerful kid shouts._int_0
#
# cheerful kid laughs._int_0
#
# joyful woman cries._int_0
#
# joyful woman shouts._int_0
#
# joyful woman laughs._int_0
#
# joyful man cries._int_0
#
# joyful man shouts._int_0
#
# joyful man laughs._int_0
#
# joyful kid cries._int_0
#
# joyful kid shouts._int_0
#
# joyful kid laughs._int_0
#
# gloomy woman cries._int_1
#
# gloomy woman shouts._int_1
#
# gloomy man cries._int_1
#
# gloomy man shouts._int_1
#
# gloomy kid cries._int_1
#
# gloomy kid shouts._int_1
#
# furious woman shouts._int_2
#
# furious woman cries._int_2
#
# furious woman snaps._int_2
#
# furious man cries._int_2
#
# furious man shouts._int_2
#
# furious man snaps._int_2
#
# furious kid cries._int_2
#
# furious kid shouts._int_2
#
# furious kid snaps._int_2
#
# terrified woman cries._int_3
#
# terrified woman shouts._int_3
#
# terrified woman snaps._int_2
#
# terrified man cries._int_3
#
# terrified man shouts._int_3
#
# terrified man snaps._int_2
#
# terrified kid cries._int_3
#
# terrified kid shouts._int_3
#
# terrified kid snaps._int_2
#
# downcast man cries._int_1
#
# downcast man shouts._int_1
#
# downcast woman cries._int_1
#
# downcast woman shouts._int_1
#
# downcast kid cries._int_1
#
# downcast kid shouts._int_1
#
# miserable man cries._int_1
#
# miserable man shouts._int_1
#
# miserable woman cries._int_1
#
# miserable woman shouts._int_1
#
# miserable kid cries._int_1
#
# miserable kid shouts._int_1

# %%
c0 = 0
c1 = 0
c2 = 0
c3 = 0
for value in labels_dict.values():
    if value == '0':
        c0 +=1
    elif value == '1':
        c1 += 1
    elif value == '2':
        c2 += 1
    elif value == '3':
        c3 += 1
print('Number of elements for each sentiment')
print('Happy: ', c0)
print('Sad: ', c1)
print('Angry: ', c2)
print('Scared: ', c3)
print('Total', len(data_psr_dict))
# Out:
# Number of elements for each sentiment
# Happy:  27
# Sad:  33
# Angry:  30
# Scared:  24
# Total 114

# %% [markdown]
# Now we have our dataset! The only problem left is the fact that the cups used in the diagrams are too resource consumming. Luckily, it is possible to remove them by transforming the states into effects (we are just doing this with the nouns as in https://github.com/CQCL/qnlp_lorenz_etal_2021_resources). Let us see some examples

# %% [markdown]
# - Intransitive sentence

# %%
from discopy import Cap, Box

woman2 = Box('woman', n.l, Ty())
words_new = (Cap(n, n.l)) >> (joyful @ Id(n) @ woman2 @ laughs)
sentence = words_new >> grammar_dict['ADJ_N_IV']
sentence = sentence.normal_form()

# %%
sentence.draw()

# %% [markdown]
# - Transitive sentence

# %%
woman2 = Box('woman', n.r, Ty())
kid2 = Box('kid', n.l, Ty())
words_new = (Cap(n.r, n) @ Cap(n, n.l)) >> (woman2 @ Id(n) @ grieves @ Id(n) @ kid2)
sentence = words_new >> grammar_dict['N_TV_N']
sentence = sentence.normal_form()
sentence.draw()

# %%
data_psr['morose man grieves woman.'].draw()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 data_psr['morose man grieves woman.'].draw()
#
# KeyError: 'morose man grieves woman.'

# %% [markdown]
# Let us apply this to our entire dataset.

# %%
# Code of this cell addapted from https://github.com/CQCL/qnlp_lorenz_etal_2021_resources
#iterates through all sentences and reshapes them as above according to their type

data_new_psr_dict = {}
for sentstr in data_psr_dict.keys(): 
    num_words = len(sentstr.split(' '))
    words = data_psr_dict[sentstr].boxes[:num_words]
    if sent_type[sentstr] == 'int':
        noun = Box(words[1].name, n.l, Ty())
        words_new = (Cap(n, n.l)) >> (words[0] @ Id(n) @ noun @ words[2])
        sentence = words_new >> grammar_dict['ADJ_N_IV']
        data_new_psr_dict[sentstr] = sentence.normal_form()
    elif 'tra' in sent_type[sentstr]:
        if sent_type[sentstr] == 'tra':
            noun1 = Box(words[0].name, n.r, Ty())
            noun2 = Box(words[2].name, n.l, Ty())
            words_new = (Cap(n.r, n) @ Cap(n, n.l)) >> (noun1 @ Id(n) @ words[1] @ Id(n) @ noun2)
            sentence = words_new >> grammar_dict['N_TV_N']
            data_new_psr_dict[sentstr] = sentence.normal_form()
    """
        elif sent_type[sentstr] == 'tra_l': #adjective at beginning
            noun1 = Box(words[1].name, n.l, Ty())
            noun2 = Box(words[3].name, n.l, Ty())
            words_new = (Cap(n, n.l) @ Cap(n, n.l)) >> (words[0] @ Id(n) @ noun1 @ words[2] @ Id(n) @ noun2)
            sentence = words_new >> grammar_dict['ADJ_N_TV_N']
            data_new_psr_dict[sentstr] = sentence.normal_form()
        elif sent_type[sentstr] == 'tra_r': #adjective on second noun
            noun1 = Box(words[0].name, n.r, Ty())
            noun2 = Box(words[3].name, n.l, Ty())
            words_new = (Cap(n.r, n) @ Cap(n, n.l)) >> (noun1 @ Id(n) @ words[1] @ words[2] @ Id(n) @ noun2)
            sentence = words_new >> grammar_dict['N_TV_ADJ_N']
            data_new_psr_dict[sentstr] = sentence.normal_form() 
    """

# %% [markdown]
# The final step before the implementation of the quantum circuit is to redefine the vocabulary according to the new domain and codamain for the nouns as effects.

# %%
vocab_psr = []
for word in vocab:
    if word.cod == Ty('n'):
        vocab_psr.append(Box(word.name, n.r, Ty()))   # n.l case is dealt with in definition of quantum functor
    else:
        vocab_psr.append(word)

# %% [markdown]
# ## 2. Create quantum circuit <a name="circuit"></a>
#
# Once the dataset and its corresponding diagrams are created, the next step is to construct the variational quantum circuits associated with them. In order to do that, we will use different ansätze depending on the type of the word that we want to represent. In this case we only have two types of words, nouns and verbs. Both types will have associated 2 qubits (as we have four sentiments, we need 4 quantum states to encode the result of the classification). Moreover, we will also distinguish between states and effects when constructing the ansätze.

# %%
# Code of this cell from https://github.com/CQCL/qnlp_lorenz_etal_2021_resources


from discopy.quantum import Ket, IQPansatz, Bra, qubit
from discopy.quantum.circuit import Functor, Id
from discopy.quantum.circuit import Circuit
from functools import reduce, partial

import numpy as np

q_s = 2 # number of qubits for type s (sentence)
q_n = 2 # number of qubits for type n (noun)
depth = 1 # depth of the IQPansatz

# Define the dimensions of the objects of the circuit functor
ob = {s: q_s, n: q_n}                          
ob_cqmap = {s: qubit ** q_s, n: qubit ** q_n}   

# Define the ansätze for states and effects
def ansatz_state(state, params):
    arity = sum(ob[Ty(factor.name)] for factor in state.cod) 
    return Ket(*tuple([0 for i in range(arity)])) >> IQPansatz(arity, params)
    
def ansatz_effect(effect, params): 
    arity = sum(ob[Ty(factor.name)] for factor in effect.dom)
    return IQPansatz(arity, params) >> Bra(*tuple([0 for i in range(arity)]))
       
def ansatz(box,params):
    dom_type = box.dom
    cod_type = box.cod
    if len(dom_type) == 0 and len(cod_type) != 0:
        return ansatz_state(box, params)
    if len(dom_type) != 0 and len(cod_type) == 0:
        return ansatz_effect(box, params)

# Construct the circuit functor
def F(params): 
    ar = dict()
    for i in range(len(vocab_psr)):
        pgbox = vocab_psr[i]
        qbox = ansatz(vocab_psr[i], params[i])
        ar.update({pgbox: qbox})
        if pgbox.cod == Ty():
            ar.update({Box(pgbox.name, n.l, Ty()): qbox})
    return Functor(ob_cqmap, ar)

# %%
# Code of this cell from https://github.com/CQCL/qnlp_lorenz_etal_2021_resources

#*****************************************************
# Functions to deal with the parametrisation
#*****************************************************

def paramshapes(vocab_psr):
    parshapes = []    
    for box in vocab_psr:
        dom_type = box.dom
        cod_type = box.cod
        dom_arity = sum(ob[Ty(factor.name)] for factor in box.dom)
        cod_arity = sum(ob[Ty(factor.name)] for factor in box.cod)
        if dom_arity == 0 or cod_arity == 0:  # states and effects
            arity = max(dom_arity, cod_arity)
            assert arity != 0
            parshapes.append((depth, arity-1))
    return parshapes

def randparams(par_shapes):
    params = np.array([]) 
    for i in range(len(par_shapes)):
        params = np.concatenate((params, np.ravel(np.random.rand(*par_shapes[i])))) # np.ravel flattens an array
    return params 

def reshape_params(unshaped_pars, par_shapes):
    pars_reshaped = [[] for ii in range(len(par_shapes))]
    shift = 0
    for ss, s in enumerate(par_shapes):
        idx0 = 0 + shift
        if len(s) == 1:
            idx1 = s[0] + shift
        elif len(s) == 2:
            idx1 = s[0] * s[1] + shift
        pars_reshaped[ss] = np.reshape(unshaped_pars[idx0:idx1], s)
        if len(s) == 1:
            shift += s[0]
        elif len(s) == 2:
            shift += s[0] * s[1]
    return pars_reshaped

# %%
#****************************************
# Parameters of the current model
#****************************************

par_shapes = paramshapes(vocab_psr)
rand_unshaped_pars = randparams(par_shapes)
rand_shaped_pars = reshape_params(rand_unshaped_pars, par_shapes)

print('Number of parameters:    ', len(rand_unshaped_pars))
# Out:
# Number of parameters:     71

# %%
# Print the quantum circuit for each sentence

func = F(rand_shaped_pars)

for sentstr in data_new_psr_dict:
    print(sentstr)
    print(data_new_psr_dict[sentstr])
    #func(data_new_psr_dict[sentstr]).draw(draw_box_labels=True, figsize=(5, 5))
# Out:
# morose woman cries.
# morose >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# morose woman shouts.
# morose >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# morose man cries.
# morose >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# morose man shouts.
# morose >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# morose kid cries.
# morose >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# morose kid shouts.
# morose >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# irascible woman cries.
# irascible >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# irascible woman shouts.
# irascible >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# irascible woman snaps.
# irascible >> Id(n) @ snaps @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# irascible man cries.
# irascible >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# irascible man shouts.
# irascible >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# irascible man snaps.
# irascible >> Id(n) @ snaps @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# irascible kid cries.
# irascible >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# irascible kid shouts.
# irascible >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# irascible kid snaps.
# irascible >> Id(n) @ snaps @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# frightened woman cries.
# frightened >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# frightened woman shouts.
# frightened >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# frightened woman snaps.
# frightened >> Id(n) @ snaps @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# frightened man cries.
# frightened >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# frightened man shouts.
# frightened >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# frightened man snaps.
# frightened >> Id(n) @ snaps @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# frightened kid cries.
# frightened >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# frightened kid shouts.
# frightened >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# frightened kid snaps.
# frightened >> Id(n) @ snaps @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# cheerful woman cries.
# cheerful >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# cheerful woman laughs.
# cheerful >> Id(n) @ laughs @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# cheerful woman shouts.
# cheerful >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# cheerful man cries.
# cheerful >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# cheerful man shouts.
# cheerful >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# cheerful man laughs.
# cheerful >> Id(n) @ laughs @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# cheerful kid cries.
# cheerful >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# cheerful kid shouts.
# cheerful >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# cheerful kid laughs.
# cheerful >> Id(n) @ laughs @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# joyful woman cries.
# joyful >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# joyful woman shouts.
# joyful >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# joyful woman laughs.
# joyful >> Id(n) @ laughs @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# joyful man cries.
# joyful >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# joyful man shouts.
# joyful >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# joyful man laughs.
# joyful >> Id(n) @ laughs @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# joyful kid cries.
# joyful >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# joyful kid shouts.
# joyful >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# joyful kid laughs.
# joyful >> Id(n) @ laughs @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# gloomy woman cries.
# gloomy >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# gloomy woman shouts.
# gloomy >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# gloomy man cries.
# gloomy >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# gloomy man shouts.
# gloomy >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# gloomy kid cries.
# gloomy >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# gloomy kid shouts.
# gloomy >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# furious woman shouts.
# furious >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# furious woman cries.
# furious >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# furious woman snaps.
# furious >> Id(n) @ snaps @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# furious man cries.
# furious >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# furious man shouts.
# furious >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# furious man snaps.
# furious >> Id(n) @ snaps @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# furious kid cries.
# furious >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# furious kid shouts.
# furious >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# furious kid snaps.
# furious >> Id(n) @ snaps @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# terrified woman cries.
# terrified >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# terrified woman shouts.
# terrified >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# terrified woman snaps.
# terrified >> Id(n) @ snaps @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# terrified man cries.
# terrified >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# terrified man shouts.
# terrified >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# terrified man snaps.
# terrified >> Id(n) @ snaps @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# terrified kid cries.
# terrified >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# terrified kid shouts.
# terrified >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# terrified kid snaps.
# terrified >> Id(n) @ snaps @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# downcast man cries.
# downcast >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# downcast man shouts.
# downcast >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# downcast woman cries.
# downcast >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# downcast woman shouts.
# downcast >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# downcast kid cries.
# downcast >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# downcast kid shouts.
# downcast >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# miserable man cries.
# miserable >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# miserable man shouts.
# miserable >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ man
# miserable woman cries.
# miserable >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# miserable woman shouts.
# miserable >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ woman
# miserable kid cries.
# miserable >> Id(n) @ cries @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# miserable kid shouts.
# miserable >> Id(n) @ shouts @ Id(n.l) >> Cup(n, n.r) @ Id(s @ n.l) >> Id(s) @ kid
# woman startles woman.
# startles >> woman @ Id(s @ n.l) >> Id(s) @ woman
# woman startles man.
# startles >> woman @ Id(s @ n.l) >> Id(s) @ man
# woman startles kid.
# startles >> woman @ Id(s @ n.l) >> Id(s) @ kid
# woman grieves woman.
# grieves >> woman @ Id(s @ n.l) >> Id(s) @ woman
# woman grieves man.
# grieves >> woman @ Id(s @ n.l) >> Id(s) @ man
# woman grieves kid.
# grieves >> woman @ Id(s @ n.l) >> Id(s) @ kid
# woman entertains woman.
# entertains >> woman @ Id(s @ n.l) >> Id(s) @ woman
# woman entertains man.
# entertains >> woman @ Id(s @ n.l) >> Id(s) @ man
# woman entertains kid.
# entertains >> woman @ Id(s @ n.l) >> Id(s) @ kid
# woman irritates woman.
# irritates >> woman @ Id(s @ n.l) >> Id(s) @ woman
# woman irritates man.
# irritates >> woman @ Id(s @ n.l) >> Id(s) @ man
# woman irritates kid.
# irritates >> woman @ Id(s @ n.l) >> Id(s) @ kid
# man startles woman.
# startles >> man @ Id(s @ n.l) >> Id(s) @ woman
# man startles man.
# startles >> man @ Id(s @ n.l) >> Id(s) @ man
# man startles kid.
# startles >> man @ Id(s @ n.l) >> Id(s) @ kid
# man grieves woman.
# grieves >> man @ Id(s @ n.l) >> Id(s) @ woman
# man grieves man.
# grieves >> man @ Id(s @ n.l) >> Id(s) @ man
# man grieves kid.
# grieves >> man @ Id(s @ n.l) >> Id(s) @ kid
# man entertains woman.
# entertains >> man @ Id(s @ n.l) >> Id(s) @ woman
# man entertains man.
# entertains >> man @ Id(s @ n.l) >> Id(s) @ man
# man entertains kid.
# entertains >> man @ Id(s @ n.l) >> Id(s) @ kid
# man irritates woman.
# irritates >> man @ Id(s @ n.l) >> Id(s) @ woman
# man irritates man.
# irritates >> man @ Id(s @ n.l) >> Id(s) @ man
# man irritates kid.
# irritates >> man @ Id(s @ n.l) >> Id(s) @ kid
# kid startles woman.
# startles >> kid @ Id(s @ n.l) >> Id(s) @ woman
# kid startles man.
# startles >> kid @ Id(s @ n.l) >> Id(s) @ man
# kid startles kid.
# startles >> kid @ Id(s @ n.l) >> Id(s) @ kid
# kid grieves woman.
# grieves >> kid @ Id(s @ n.l) >> Id(s) @ woman
# kid grieves man.
# grieves >> kid @ Id(s @ n.l) >> Id(s) @ man
# kid grieves kid.
# grieves >> kid @ Id(s @ n.l) >> Id(s) @ kid
# kid entertains woman.
# entertains >> kid @ Id(s @ n.l) >> Id(s) @ woman
# kid entertains man.
# entertains >> kid @ Id(s @ n.l) >> Id(s) @ man
# kid entertains kid.
# entertains >> kid @ Id(s @ n.l) >> Id(s) @ kid
# kid irritates woman.
# irritates >> kid @ Id(s @ n.l) >> Id(s) @ woman
# kid irritates man.
# irritates >> kid @ Id(s @ n.l) >> Id(s) @ man
# kid irritates kid.
# irritates >> kid @ Id(s @ n.l) >> Id(s) @ kid

# %% [markdown]
# ## 3. Create training and test dataset <a name="dataset"></a>
#
# The next step is to divide our dataset into training and test data, so we can perform the classification using a supervised quantum machine learning technique. We need the data, which are the quantum circuits associated to each sentences, and the labels, that encode the sentiment. In this case the labels are the four possible quantum states that can be obtained from measuring a 2-qubit quantum circuit:
#
# - Happy: $ \ 0 \ \rightarrow \ |00\rangle = [1,0,0,0] \ \rightarrow \ p_{00}=1$,
# - Sad: $ \ 1 \ \rightarrow \ |01\rangle = [0,1,0,0] \ \rightarrow \ p_{01}=1$,
# - Angry: $ \ 2 \ \rightarrow \ |10\rangle = [0,0,1,0] \ \rightarrow \ p_{10}=1$,
# - Scared: $ \ 3 \ \rightarrow \ |11\rangle = [0,0,0,1] \ \rightarrow \ p_{11}=1$.

# %%
from sklearn.model_selection import train_test_split

psr_diagrams = []
psr_diagrams_dict = {}
psr_labels = []
sentences = []

for sentstr in data_new_psr_dict.keys():
    sentences.append(sentstr)
    diagram = data_new_psr_dict[sentstr]
    psr_diagrams.append(diagram)
    psr_diagrams_dict[sentstr] = diagram
    label = int(labels_dict[sentstr])
    psr_labels.append(label)

#create lists of sentences and corresponding diagram and labels
train_data_psr, test_data_psr, orig_train_labels, orig_test_labels = \
    train_test_split(psr_diagrams, psr_labels, test_size=0.25, random_state=42)
train_sent, test_sent, train_labels_sent, test_labels_sent = \
    train_test_split(sentences, psr_labels, test_size=0.25, random_state=42)

# %% [markdown]
# Since we are doing all versus one, we will actually require 4 different binary classifiers.We can then combine the classifiers to produce a single prediction, as in the image below:
#
# ![image.png](attachment:image.png)
# (source: https://www.researchgate.net/figure/The-considered-one-vs-all-multiclass-classification-approach_fig2_257018675)
#
# As such, we will need a different set of labels for each classifier.

# %%
def num_to_vec(x):
    if x:
        return [0,1] #True
    else:
        return [1,0]

data_sets_labels = {}
for i, cla in enumerate(['happy', 'sad', 'angry', 'scared']):
    data_sets_labels[cla] = {}
    
    tr_labels = [num_to_vec(i == t) for t in orig_train_labels]
    data_sets_labels[cla]['train'] = tr_labels
    
    te_labels = [num_to_vec(i == t) for t in orig_test_labels]
    data_sets_labels[cla]['test'] = te_labels

# %% [markdown]
# ## 4. Optimization - Qiskit Implementation <a name="optimization"></a>
#
# Finally, we need to apply a variational algorithm to our circuits so it can learn sentiment classification. We will be using the SPSA optimization algorithm (from qiskit.algorithms.optimizers) which is well-known for being robust against noise. We have chosen to use cross entropy for our cost function.

# %%
# !pip install pytket-qiskit
# Out:
# Requirement already satisfied: pytket-qiskit in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.43.0)
# Requirement already satisfied: pytket~=1.18 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket-qiskit) (1.18.0)
# Requirement already satisfied: qiskit~=0.44.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket-qiskit) (0.44.1)
# Requirement already satisfied: qiskit-ibm-runtime~=0.11.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket-qiskit) (0.11.3)
# Requirement already satisfied: qiskit-aer~=0.12.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket-qiskit) (0.12.2)
# Requirement already satisfied: qiskit-ibm-provider~=0.6.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket-qiskit) (0.6.3)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket-qiskit) (1.25.2)
# Requirement already satisfied: sympy~=1.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket~=1.18->pytket-qiskit) (1.12)
# Requirement already satisfied: lark-parser~=0.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket~=1.18->pytket-qiskit) (0.12.0)
# Requirement already satisfied: scipy<2.0,>=1.7.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket~=1.18->pytket-qiskit) (1.10.1)
# Requirement already satisfied: networkx>=2.8.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket~=1.18->pytket-qiskit) (3.1)
# Requirement already satisfied: graphviz~=0.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket~=1.18->pytket-qiskit) (0.20.1)
# Requirement already satisfied: jinja2~=3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket~=1.18->pytket-qiskit) (3.1.2)
# Requirement already satisfied: types-pkg-resources in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket~=1.18->pytket-qiskit) (0.1.3)
# Requirement already satisfied: typing-extensions~=4.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket~=1.18->pytket-qiskit) (4.7.1)
# Requirement already satisfied: qwasm~=1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytket~=1.18->pytket-qiskit) (1.0.1)
# Requirement already satisfied: qiskit-terra==0.25.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit~=0.44.0->pytket-qiskit) (0.25.1)
# Requirement already satisfied: rustworkx>=0.13.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra==0.25.1->qiskit~=0.44.0->pytket-qiskit) (0.13.1)
# Requirement already satisfied: ply>=3.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra==0.25.1->qiskit~=0.44.0->pytket-qiskit) (3.11)
# Requirement already satisfied: psutil>=5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra==0.25.1->qiskit~=0.44.0->pytket-qiskit) (5.9.5)
# Requirement already satisfied: dill>=0.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra==0.25.1->qiskit~=0.44.0->pytket-qiskit) (0.3.6)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra==0.25.1->qiskit~=0.44.0->pytket-qiskit) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra==0.25.1->qiskit~=0.44.0->pytket-qiskit) (5.1.0)
# Requirement already satisfied: symengine<0.10,>=0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra==0.25.1->qiskit~=0.44.0->pytket-qiskit) (0.9.2)
# Requirement already satisfied: requests>=2.19 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-ibm-provider~=0.6.3->pytket-qiskit) (2.31.0)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-ibm-provider~=0.6.3->pytket-qiskit) (1.2.0)
# Requirement already satisfied: urllib3>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-ibm-provider~=0.6.3->pytket-qiskit) (1.26.9)
# Requirement already satisfied: websocket-client>=1.5.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-ibm-provider~=0.6.3->pytket-qiskit) (1.6.1)
# Requirement already satisfied: websockets>=10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-ibm-provider~=0.6.3->pytket-qiskit) (10.4)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-ibm-runtime~=0.11.3->pytket-qiskit) (0.39.0)
# Requirement already satisfied: ibm-cloud-sdk-core<4.0.0,>=3.16.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime~=0.11.3->pytket-qiskit) (3.16.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2~=3.0->pytket~=1.18->pytket-qiskit) (2.1.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.25.1->qiskit~=0.44.0->pytket-qiskit) (1.16.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qwasm~=1.0->pytket~=1.18->pytket-qiskit) (62.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibm-provider~=0.6.3->pytket-qiskit) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibm-provider~=0.6.3->pytket-qiskit) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibm-provider~=0.6.3->pytket-qiskit) (2022.12.7)
# Requirement already satisfied: cryptography>=1.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-provider~=0.6.3->pytket-qiskit) (37.0.2)
# Requirement already satisfied: pyspnego>=0.1.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-provider~=0.6.3->pytket-qiskit) (0.9.1)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sympy~=1.6->pytket~=1.18->pytket-qiskit) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-provider~=0.6.3->pytket-qiskit) (1.15.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.16.7->ibm-platform-services>=0.22.6->qiskit-ibm-runtime~=0.11.3->pytket-qiskit) (2.8.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from stevedore>=3.0.0->qiskit-terra==0.25.1->qiskit~=0.44.0->pytket-qiskit) (5.11.1)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-provider~=0.6.3->pytket-qiskit) (2.21)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
from qiskit import BasicAer, execute, ClassicalRegister
from pytket.extensions.qiskit import tk_to_qiskit
from qiskit.quantum_info import Statevector

# %% [markdown]
# Each of our discopy diagrams contain effects (downwards pointing triangles) which correspond to a measurement outcome of $0$ on that qubit. Therefore, we will need to post-select our measurement results to have zeros except for the qubit without the effect, which is the sentence type we wish to classify.
#
# This means that we need to find where the sentence qubit is (and how many other qubits there are) for each of our different grammatical types. We can see that for the intransitive sentence there are four qubits and the sentence qubit is the 3rd one, while the remaining have 0 effects.

# %%
func(data_new_psr_dict['morose woman cries.']).draw()

# %% [markdown]
# We observe the structure for the other grammar

# %%
func(data_new_psr_dict['woman grieves man.']).draw()

# %%
def get_qiskit_results(circ, sent, retries=10):
    """Function to get the Qiskit's results from a DisCoPy circuit.
    
    Args:
        circ: DisCoPy circuit.
        sent: English sentence for circ
            
    Returns:
        array: results from the postselection measurement.
    """
    
    #Finds the sentence's type to determine the number of qubits and position of the sentence qubits    
    s_type = sent_type[sent]
    
    if s_type == 'int':
        n_qubits = 4
        post = 2
    elif s_type == 'tra':
        n_qubits = 3
        post = 1
    elif s_type == 'tra_l':
        n_qubits = 5
        post = 2
    else:
        assert s_type == 'tra_r'
        n_qubits = 5
        post = 1
    
    #the diagrams are initially in discopy, so we first convert them to tket and then to qiskit    
    qc = tk_to_qiskit(circ.to_tk())
    

    
    qc.remove_final_measurements()
    print(qc)
    state_dict = Statevector(qc).to_dict()
    print(state_dict)
    #["00000": 74278498274, "000010"]
    #The only values we care about are the ones when the non-sentence qubits are all zero.
    #This leaves only two possible states - the sentence qubit is 0 or 1 (and the rest are all 0)
    selections = ['0' * post + val + '0' * (3 - post - 1) for val in ['0', '1']]

    # ["000" "010"]
    print(selections)
    return [np.abs(state_dict[sel])**2 for sel in selections] #returns the amplitude for the two states

# %%
# !pip install qiskit_algorithms
# Out:
# Requirement already satisfied: qiskit_algorithms in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.1.0)
# Requirement already satisfied: qiskit-terra>=0.24 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit_algorithms) (0.25.1)
# Requirement already satisfied: scipy>=1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit_algorithms) (1.10.1)
# Requirement already satisfied: numpy>=1.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit_algorithms) (1.25.2)
# Requirement already satisfied: rustworkx>=0.13.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra>=0.24->qiskit_algorithms) (0.13.1)
# Requirement already satisfied: ply>=3.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra>=0.24->qiskit_algorithms) (3.11)
# Requirement already satisfied: psutil>=5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra>=0.24->qiskit_algorithms) (5.9.5)
# Requirement already satisfied: sympy>=1.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra>=0.24->qiskit_algorithms) (1.12)
# Requirement already satisfied: dill>=0.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra>=0.24->qiskit_algorithms) (0.3.6)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra>=0.24->qiskit_algorithms) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra>=0.24->qiskit_algorithms) (5.1.0)
# Requirement already satisfied: symengine<0.10,>=0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from qiskit-terra>=0.24->qiskit_algorithms) (0.9.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit-terra>=0.24->qiskit_algorithms) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from stevedore>=3.0.0->qiskit-terra>=0.24->qiskit_algorithms) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sympy>=1.3->qiskit-terra>=0.24->qiskit_algorithms) (1.3.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
from qiskit_algorithms.optimizers import SPSA
import time


global_costs = [] #global variable to keep track of cost during training


def cost_ce(unshaped_params): #finds cross entropy cost
    
    #creates a functor which turns a sentence diagram into a circuit parameterized by unshaped_params
    func = F(reshape_params(unshaped_params, par_shapes)) 
    
    #Applies this functor to every training diagram
    circs = [func(diag) for diag in train_data_psr]
    
    #Finds the post-selected qiskit results for each circuit
    results = np.array([get_qiskit_results(circs[i], train_sent[i]) for i in range(len(train_sent))])

    #Turns each result into a probability distribution
    results_tweaked = [np.abs(np.array(res) - 1e-9) for res in results] 
    pred_labels_distrs = [res.flatten() / np.sum(res) for res in results_tweaked]
    
    
    #finds the cross entropy
    cross_entropies = np.array([np.sum(train_labels[s] * np.log2(pred_labels_distrs[s])) for s in range(len(train_labels))])
    cost = -1 / len(train_data_psr) * np.sum(cross_entropies)
    
    #stores the cost in a global list so we can track progress
    global_costs.append(cost)
    
    if len(global_costs) % 100 == 0: #since SPSA calls the cost function twice per iteration, this prints every 50 iterations
        print("at iteration", len(global_costs)/2, time.time() - begin_time)
       
    
    return cost



rand_unshaped_pars = randparams(par_shapes)
num_vars = len(rand_unshaped_pars)

bounds = [[0.0, 1.0] for _ in range(len(rand_unshaped_pars))]

ps = {}


n_iterations = 1000

#creates a classifier 1vall classifier for each sentiment
for cla in ['happy', 'sad', 'angry', 'scared']:
    
    #chooses random starting parameters
    rand_unshaped_pars = randparams(par_shapes)


    #finds the labels for the current classifier
    train_labels = data_sets_labels[cla]['train']
    test_labels = data_sets_labels[cla]['test']




    a = time.time()

    #creates a qiskit optimizer
    opt = SPSA(maxiter=n_iterations)
    
    print("\n\ncalibrating", cla)
    opt.calibrate(cost_ce, initial_point=rand_unshaped_pars) #calibrates according to cost function
    print("training")
    global_costs = []
    o = opt.optimize(num_vars, cost_ce, initial_point=rand_unshaped_pars, variable_bounds=bounds) #performs optimization
    ps[cla] = [o, global_costs.copy()] #saves parameters and cost history
    print("took", time.time() - a)
# Out:
# calibrating happy
#      ┌───┐                  ┌───┐                                 »
# q_0: ┤ H ├──────■───────────┤ H ├─────────────────────────■───────»
#      ├───┤┌─────┴──────┐    └───┘         ┌───┐     ┌─────┴─────┐ »
# q_1: ┤ H ├┤ Rz(1.7954) ├──────■───────────┤ H ├─────┤ Rz(4.142) ├─»
#      ├───┤└────────────┘┌─────┴──────┐    └───┘     └───────────┘ »
# q_2: ┤ H ├──────────────┤ Rz(11.543) ├──────■─────────────────────»
#      ├───┤              └────────────┘┌─────┴──────┐              »
# q_3: ┤ H ├────────────────────────────┤ Rz(1.5307) ├──────■───────»
#      ├───┤                            └────────────┘┌─────┴──────┐»
# q_4: ┤ H ├──────────────────────────────────────────┤ Rz(1.9329) ├»
#      ├───┤                                          └────────────┘»
# q_5: ┤ H ├────────────────────────────────────────────────────────»
#      └───┘                                                        »
# «
# «q_0: ─────────────────────────────────
# «
# «q_1: ─────────────────────────────────
# «
# «q_2: ─────────────────────────────────
# «
# «q_3: ─────────────────────────────────
# «                    ┌───┐
# «q_4: ───────■───────┤ H ├──────■──────
# «     ┌──────┴──────┐├───┤┌─────┴─────┐
# «q_5: ┤ Rz(0.13599) ├┤ H ├┤ Rz(4.142) ├
# «     └─────────────┘└───┘└───────────┘
# {'000000': (0.3315753752774303+0.08677259269556496j), '000001': (-0.033954795680881944-0.13624290988871027j), '000010': (0.07380489278748018-0.28202320874722503j), '000011': (-0.12009203812011666-0.11326764484303463j), '000100': (0.23062059415873834-0.3766026554289423j), '000101': (-0.04149588679084684-0.0020458140881516487j), '000110': (-0.07356162499297983-0.045047015517829324j), '000111': (-0.1844647143490325+0.1058932992077063j), '001000': (0.18848606285431244+0.048989212695776475j), '001001': (-0.01942302904097834-0.07738186762221172j), '001010': (0.041668036858597234-0.1603178288068808j), '001011': (-0.06834495208485039-0.06424517537196382j), '001100': (0.21926866390991584+0.12199986579613464j), '001101': (0.0001778703801770208-0.023606257297420576j), '001110': (0.02383017816660732-0.042829648157635826j), '001111': (-0.06448934779796833-0.10221310839129967j), '010000': (-9.586674486268625e-05-0.0003846633154386714j), '010001': (-0.00011944204027218537+0.00011004021044698758j), '010010': (-0.00032717744017205755+8.153997254984324e-05j), '010011': (-4.834055452991416e-05+0.00018471889581091742j), '010100': (-0.0005101601752101252-2.5151718745513874e-05j), '010101': (2.0942714180507685e-05+4.3250549917153787e-05j), '010110': (-4.912873755968467e-06+9.964935444339005e-05j), '010111': (0.0002098033565131008+0.00012847751878020952j), '011000': (-0.27372056347967094+0.06798517314295636j), '011001': (0.07821948913616668+0.0850387502575825j), '011010': (0.05782515260962843+0.2328144891581454j), '011011': (0.13138953069346038+0.034496516289451794j), '011100': (-0.3633727259337673-0.00363692763500668j), '011101': (0.016095603488734896+0.030161909951438113j), '011110': (-0.0007103994168820703+0.07097742889617016j), '011111': (0.15273523707336342+0.0854765115725296j), '100000': (0.0029510882530047675-0.011276696530203755j), '100001': (-0.004633546589282744+0.0011547839652386986j), '100010': (-0.009591454542894813-0.0025100638963682816j), '100011': (-0.003852170434903655+0.004084264304733475j), '100100': (-0.012808049615227706-0.00784327983273009j), '100101': (-6.957701430631907e-05+0.0014112523350099395j), '100110': (-0.0015320242740007803+0.0025017904921932578j), '100111': (0.00360137298720763+0.0062735436927555096j), '101000': (0.01095626047928451-0.003979090702836598j), '101001': (-0.0035830690558124392-0.003156722373397046j), '101010': (-0.003384436877953562-0.00931890594605488j), '101011': (-0.005549712800781727-0.0008491877291301589j), '101100': (0.014951166235854373-0.0014233065967996176j), '101101': (-0.0007921152903186782-0.001170054477720649j), '101110': (-0.0002780138286719113-0.0029204044846601936j), '101111': (-0.006647726231664143-0.0028521875476107115j), '110000': (-0.008479769191932983-0.007997894783183654j), '110001': (-0.001208967383721944+0.004619705387416242j), '110010': (-0.00680265218154056+0.007212513037024647j), '110011': (0.0017363580648179582+0.005339053534214421j), '110100': (-0.01302516158624193+0.007477187916117421j), '110101': (0.0012049825147254166+0.0007378965057491462j), '110110': (0.0014605157068289761+0.002544198874510806j), '110111': (0.007232173838350757-0.00015132557541949263j), '111000': (0.0017630876472171353-0.011522340407207309j), '111001': (-0.004488432886929133+0.0016301074262020498j), '111010': (-0.009800388256213198-0.0014996036275454312j), '111011': (-0.003406819365340193+0.004462512048432913j), '111100': (0.0059217255033700645-0.013802041173079491j), '111101': (-0.0014066071283435771+0.0001339048187475591j), '111110': (-0.0026959464100308455-0.0011566879428774072j), '111111': (-0.005691033386964927+0.004465352936370409j)}
# ['000', '010']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 69
#      66 opt = SPSA(maxiter=n_iterations)
#      68 print("\n\ncalibrating", cla)
# ---> 69 opt.calibrate(cost_ce, initial_point=rand_unshaped_pars) #calibrates according to cost function
#      70 print("training")
#      71 global_costs = []
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/qiskit_algorithms/optimizers/spsa.py:334, in SPSA.calibrate(loss, initial_point, c, stability_constant, target_magnitude, alpha, gamma, modelspace, max_evals_grouped)
#     331     pert = bernoulli_perturbation(dim)
#     332     points += [initial_point + c * pert, initial_point - c * pert]
# --> 334 losses = _batch_evaluate(loss, points, max_evals_grouped)
#     336 avg_magnitudes = 0.0
#     337 for i in range(steps):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/qiskit_algorithms/optimizers/spsa.py:692, in _batch_evaluate(function, points, max_evals_grouped, unpack_points)
#     689 # if the function cannot handle lists of points as input, cover this case immediately
#     690 if max_evals_grouped is None or max_evals_grouped == 1:
#     691     # support functions with multiple arguments where the points are given in a tuple
# --> 692     return [
#     693         function(*point) if isinstance(point, tuple) else function(point) for point in points
#     694     ]
#     696 num_points = len(points)
#     698 # get the number of batches
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/qiskit_algorithms/optimizers/spsa.py:693, in <listcomp>(.0)
#     689 # if the function cannot handle lists of points as input, cover this case immediately
#     690 if max_evals_grouped is None or max_evals_grouped == 1:
#     691     # support functions with multiple arguments where the points are given in a tuple
#     692     return [
# --> 693         function(*point) if isinstance(point, tuple) else function(point) for point in points
#     694     ]
#     696 num_points = len(points)
#     698 # get the number of batches
#
# Cell In[40], line 17, in cost_ce(unshaped_params)
#      14 circs = [func(diag) for diag in train_data_psr]
#      16 #Finds the post-selected qiskit results for each circuit
# ---> 17 results = np.array([get_qiskit_results(circs[i], train_sent[i]) for i in range(len(train_sent))])
#      19 #Turns each result into a probability distribution
#      20 results_tweaked = [np.abs(np.array(res) - 1e-9) for res in results]
#
# Cell In[40], line 17, in <listcomp>(.0)
#      14 circs = [func(diag) for diag in train_data_psr]
#      16 #Finds the post-selected qiskit results for each circuit
# ---> 17 results = np.array([get_qiskit_results(circs[i], train_sent[i]) for i in range(len(train_sent))])
#      19 #Turns each result into a probability distribution
#      20 results_tweaked = [np.abs(np.array(res) - 1e-9) for res in results]
#
# Cell In[38], line 45, in get_qiskit_results(circ, sent, retries)
#      43 # ["000" "010"]
#      44 print(selections)
# ---> 45 return [np.abs(state_dict[sel])**2 for sel in selections]
#
# Cell In[38], line 45, in <listcomp>(.0)
#      43 # ["000" "010"]
#      44 print(selections)
# ---> 45 return [np.abs(state_dict[sel])**2 for sel in selections]
#
# KeyError: '000'

# %% [markdown]
# ## 5. Results <a name="results"></a>

# %% [markdown]
# We can now analyze the predictions of our models. We will collect the individual predictions for each binary classifer, as well as keeping track of the highest value to determine the final prediction for each test sentence.

# %%
final_train_predictions = [(0,'') for _ in range(len(orig_train_labels))] # list of tuples of the form (probability, class)
final_test_predictions = [(0,'') for _ in range(len(orig_test_labels))]

test_predictions_dict = {}

individual_train_predictions = {}
individual_test_predictions = {}
classes = ['happy', 'sad', 'angry', 'scared']
for j, cla in enumerate(classes):
    
    params = ps[cla][0][0]
    func = F(reshape_params(params, par_shapes))
    
    
    train_data = train_data_psr
    #train_data = data_sets[cla]['train']
    
    train_labels = data_sets_labels[cla]['train']
    test_labels = data_sets_labels[cla]['test']
    print(test_labels)
    
    
    final_train_circuits = [func(diag) for diag in train_data_psr]
    train_results = [get_qiskit_results(final_train_circuits[i], train_sent[i]) for i in range(len(train_sent))]

    final_test_circuits = [func(diag) for diag in test_data_psr]
    test_results = [get_qiskit_results(final_test_circuits[i], test_sent[i]) for i in range(len(test_sent))]

    train_results_tweaked = [np.abs(np.array(res) - 1e-9) for res in train_results]
    test_results_tweaked = [np.abs(np.array(res) - 1e-9) for res in test_results]
    pred_train_results = [res.flatten() / np.sum(res) for res in train_results_tweaked]
    pred_test_results = [res.flatten() / np.sum(res) for res in test_results_tweaked]
    
    
    test_predictions_dict[cla] = ([np.argmax(r) for r in pred_test_results], test_labels)
    
    
    
    #Since each tuple (p, j) in these lists represents a probability that sentence i is in class j, this update keeps 
    #track of the most likely prediction so far
    final_train_predictions = [max(final_train_predictions[i], (pred_train_results[i][1], j)) for i in range(len(pred_train_results))]
    final_test_predictions = [max(final_test_predictions[i], (pred_test_results[i][1], j)) for i in range(len(pred_test_results))]
    
    individual_train_predictions[cla] = [np.argmax(pred) for pred in pred_train_results]
    individual_test_predictions[cla] = [np.argmax(pred) for pred in pred_test_results]

# %% [markdown]
# Compute and print accuracies

# %%
#individual accuracy

for cla in classes:
    train_pred = individual_train_predictions[cla]
    train_actual = data_sets_labels[cla]['train']
    
    acc = [train_pred[i] == np.argmax(train_actual[i]) for i in range(len(train_pred))]
    print("\n\nfor", cla, ": train accuracy =", sum(acc)/len(acc))
    

    test_pred = individual_test_predictions[cla]
    test_actual = data_sets_labels[cla]['test']
    
    acc = [test_pred[i] == np.argmax(test_actual[i]) for i in range(len(test_pred))]
    print("for", cla, ": test accuracy =", sum(acc)/len(acc))

# %% [markdown]
# Print confusion matrices for each binary classifier

# %%
from sklearn.metrics import confusion_matrix
for cla in classes:
    
    print("\n\n for", cla, "\n", confusion_matrix([np.argmax(t) for t in test_predictions_dict[cla][1]], test_predictions_dict[cla][0])) #true, pred
    
confusion_matrix(orig_test_labels, [r[1] for r in final_test_predictions])
# Out:
#  for happy
#  [[23  0]
#  [ 4  2]]
#
#
#  for sad
#  [[12  5]
#  [ 6  6]]
#
#
#  for angry
#  [[19  4]
#  [ 2  4]]
#
#
#  for scared
#  [[24  0]
#  [ 0  5]]
# array([[ 2,  4,  0,  0],
#        [ 0, 10,  2,  0],
#        [ 0,  1,  5,  0],
#        [ 0,  0,  0,  5]])

# %%
correct = 0
for i, res in enumerate(final_train_predictions):
    pred_result = res[1]
    train_result = orig_train_labels[i]
    #print(train_sent[i])
    #print(res.flatten())
    #print(pred_result,train_result)
    if train_result == pred_result:
        correct += 1
    #print(f'Result: {train_array, train_result}, Predicted result: {res, pred_result}')
print('Correct overall predictions (train):',correct/len(train_results_tweaked))

correct = 0
for i, res in enumerate(final_test_predictions):
    pred_result = res[1]
    test_result = orig_test_labels[i]
    if test_result == pred_result:
        correct += 1
print('Correct overall predictions (test):',correct/len(test_results_tweaked))
# Out:
# Correct overall predictions (train): 0.7647058823529411
# Correct overall predictions (test): 0.7586206896551724

# %%
pickle.dump(ps, open("results/sentiment_analysis_qiskit_1vall.p", "wb"))

# %% [markdown]
# ### Plotting cost

# %%
fig, axs = plt.subplots(2,2, figsize=(15,10))
import matplotlib.pyplot as plt

colours = ['blue', 'red', 'orange', 'green']

for i in range(4):
    costs = ps[classes[i]][1][51:] #excluding the first 51 values since they are used for calibration
    
    n = ps[cla][0][-1]
    costs = [(costs[j*2] + costs[j*2 + 1])/2 for j in range(n//2)] #averages over xplus and xminus values
    
    axs[i//2, i%2].plot(ps[classes[i]][1][51:], color=colours[i]) 
    axs[i//2, i%2].set_title(classes[i])

    axs[i//2, i%2].set_xlabel('iterations')
    axs[i//2, i%2].set_ylabel('cost')
    axs[i//2, i%2].set_ylim(0,2.5)
